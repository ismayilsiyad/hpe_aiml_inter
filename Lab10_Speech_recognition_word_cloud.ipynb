# %% [markdown]
# # Speech Recognition
#
# For speech recognition we are using the module named speech_recognition.  It is library for performing speech recognition, with support for several engines and APIs, online and offline.

# %%
# %pip install SpeechRecognition==3.8 pydub
# Out:
# Requirement already satisfied: SpeechRecognition==3.8 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (3.8.0)
# Requirement already satisfied: pydub in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (0.25.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
r = sr.Recognizer()

# %%
sr.__version__
# Out:
# '3.8.0'

# %%
filename = "test.wav"

# %%
# open the file
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    print(text)
# Out:
# India is my country in all Indians are my brothers and sisters I love my country and I am proud of its rich and varied Heritage I shall always strive to be worthy of it I shall give respect to my parents teachers and elders and treat everyone with courtesy to my country and my people I pledge my devotion in their well-being and prosperity zalone lies my happiness

# %% [markdown]
# # Word Cloud from recognized text
#
# we are using the library wordcloud for plotting the wordcloud from the recognized text

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from wordcloud) (1.21.0)
# Requirement already satisfied: pillow in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: matplotlib in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: cycler>=0.10 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: six>=1.5 in /home/amits/environments/hpepyspark/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
#Count the words collected from audio on Cloud
class WordCloudGeneration:

    def create_word_cloud(self, final_data):
        # initiate WordCloud object with parameters width, height, maximum font size and background color
        # call the generate method of WordCloud class to generate an image
        wordcloud = WordCloud(width=1600, height=800, max_words=10, max_font_size=200, background_color="black").generate(final_data)
        # plt the image generated by WordCloud class
        plt.figure(figsize=(12,10))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()

wordcloud_generator = WordCloudGeneration()
wordcloud_generator.create_word_cloud(text)
